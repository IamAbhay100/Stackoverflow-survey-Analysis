# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Survey Dataset Exploration Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# -   Load the dataset that will used thru the capstone project.
# -   Explore the dataset.
# -   Get familier with the data types.

# %% [markdown]
# ## Load the dataset

# %% [markdown]
# Import the required libraries.

# %%
import pandas as pd

# %% [markdown]
# The dataset is available on the IBM Cloud at the below url.

# %%
dataset_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv"

# %% [markdown]
# Load the data available at dataset_url into a dataframe.

# %%
# your code goes 
df= pd.read_csv(dataset_url)

# %% [markdown]
# ## Explore the data set

# %% [markdown]
# It is a good idea to print the top 5 rows of the dataset to get a feel of how the dataset will look.

# %% [markdown]
# Display the top 5 rows and columns from your dataset.

# %%
# your code goes here
df.head(20)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            4                     I am a developer by profession       No
# 1            9                     I am a developer by profession      Yes
# 2           13                     I am a developer by profession      Yes
# 3           16                     I am a developer by profession      Yes
# 4           17                     I am a developer by profession      Yes
# 5           19                     I am a developer by profession      Yes
# 6           20  I am not primarily a developer, but I write co...       No
# 7           22                     I am a developer by profession      Yes
# 8           23                     I am a developer by profession      Yes
# 9           24                     I am a developer by profession      Yes
# 10          25                     I am a developer by profession       No
# ...

# %% [markdown]
# ## Find out the number of rows and columns

# %% [markdown]
# Start by exploring the numbers of rows and columns of data in the dataset.

# %% [markdown]
# Print the number of rows in the dataset.

# %%
# your code goes here
df.shape
# Out:
# (11552, 85)

# %% [markdown]
# Print the number of columns in the dataset.

# %%
# your code goes here
df.columns.value_counts()
# Out:
# Respondent        1
# OpSys             1
# Extraversion      1
# SocialMedia       1
# OffOn             1
#                  ..
# CurrencySymbol    1
# ResumeUpdate      1
# JobFactors        1
# FizzBuzz          1
# SurveyEase        1
# Name: count, Length: 85, dtype: int64

# %% [markdown]
# ## Identify the data types of each column

# %% [markdown]
# Explore the dataset and identify the data types of each column.

# %% [markdown]
# Print the datatype of all columns.

# %%
# your code goes here
df.dtypes
# Out:
# Respondent       int64
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
# OpenSource      object
#                  ...
# Sexuality       object
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Length: 85, dtype: object

# %% [markdown]
# Print the mean age of the survey participants.

# %%
# your code goes here
# df.describe()
print(df['Age'].dtype)
df['Age'].mean()
# Out:
# float64
# 30.77239449133718

# %% [markdown]
# The dataset is the result of a world wide survey. Print how many unique countries are there in the Country column.

# %%
# your code goes here
df_country=df['Country'].unique()
count=0
for i in df_country:
    count =count + 1

print(count)
# Out:
# 135

# %% [markdown]
# ### Finding duplicates
# ##### We will find the duplicates in Respondent

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11552 entries, 0 to 11551
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11552 non-null  int64
#  1   MainBranch              11552 non-null  object
#  2   Hobbyist                11552 non-null  object
#  3   OpenSourcer             11552 non-null  object
#  4   OpenSource              11471 non-null  object
#  5   Employment              11552 non-null  object
#  6   Country                 11552 non-null  object
#  7   Student                 11499 non-null  object
#  8   EdLevel                 11436 non-null  object
#  9   UndergradMajor          10812 non-null  object
#  10  EduOther                11388 non-null  object
#  11  OrgSize                 11454 non-null  object
#  12  DevType                 11485 non-null  object
#  13  YearsCode               11543 non-null  object
# ...

# %%
df_country=df['Respondent'].unique()
count=0
for i in df_country:
    count =count + 1

print(count)
# Out:
# 11398

# %%
11552-11398
# Out:
# 154

# %% [markdown]
# ### 154 duplicates

# %%
df.drop_duplicates(subset=['Respondent'],inplace=True)

# %%
df.shape
# Out:
# (11398, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11398 entries, 0 to 11551
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11398 non-null  int64
#  1   MainBranch              11398 non-null  object
#  2   Hobbyist                11398 non-null  object
#  3   OpenSourcer             11398 non-null  object
#  4   OpenSource              11317 non-null  object
#  5   Employment              11398 non-null  object
#  6   Country                 11398 non-null  object
#  7   Student                 11347 non-null  object
#  8   EdLevel                 11286 non-null  object
#  9   UndergradMajor          10661 non-null  object
#  10  EduOther                11234 non-null  object
#  11  OrgSize                 11302 non-null  object
#  12  DevType                 11333 non-null  object
#  13  YearsCode               11389 non-null  object
# ...

# %%
df_schema= pd.read_csv('D:\Coursera practice\Final Project\data schema csv.csv',index_col=0)
df_schema
# Out:
#                                                   Question Text
# Column Name
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
df_schema.loc['Respondent']
# Out:
# Question Text    Randomized respondent ID number (not in order ...
# Name: Respondent, dtype: object

# %%
selected_columns=['Country',
                  'Age',
                  'Gender',
                  'EdLevel',
                  'UndergradMajor',
                  'OrgSize',
                  'YearsCode',
                  'YearsCodePro',
                  'JobSat',
                  'JobSeek',
                  'CurrencySymbol',
                  'LanguageWorkedWith',
                  'LanguageDesireNextYear','OpenSource','Hobbyist','Student','Age1stCode','WorkWeekHrs','WorkLoc']

# %%
df_selected =df[selected_columns]
df_selected
# Out:
#               Country   Age Gender  \
# 0       United States  22.0    Man
# 1         New Zealand  23.0    Man
# 2       United States  28.0    Man
# 3      United Kingdom  26.0    Man
# 4           Australia  29.0    Man
# ...               ...   ...    ...
# 11547   United States  36.0    Man
# 11548          Poland  25.0    Man
# 11549   United States  34.0    Man
# 11550     Switzerland  25.0    Man
# 11551  United Kingdom  30.0    Man
#
#                                                  EdLevel  \
# 0               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1      Some college/university study without earning ...
# 2            Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3            Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 11547        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11548        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ...

# %%
df_selected.dtypes
# Out:
# Country                    object
# Age                       float64
# Gender                     object
# EdLevel                    object
# UndergradMajor             object
# OrgSize                    object
# YearsCode                  object
# YearsCodePro               object
# JobSat                     object
# JobSeek                    object
# CurrencySymbol             object
# LanguageWorkedWith         object
# LanguageDesireNextYear     object
# OpenSource                 object
# Hobbyist                   object
# Student                    object
# Age1stCode                 object
# WorkWeekHrs               float64
# WorkLoc                    object
# dtype: object

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11398 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 11398 non-null  object
#  1   Age                     11111 non-null  float64
#  2   Gender                  11325 non-null  object
#  3   EdLevel                 11286 non-null  object
#  4   UndergradMajor          10661 non-null  object
#  5   OrgSize                 11302 non-null  object
#  6   YearsCode               11389 non-null  object
#  7   YearsCodePro            11382 non-null  object
#  8   JobSat                  11397 non-null  object
#  9   JobSeek                 11398 non-null  object
#  10  CurrencySymbol          11398 non-null  object
#  11  LanguageWorkedWith      11387 non-null  object
#  12  LanguageDesireNextYear  11264 non-null  object
#  13  OpenSource              11317 non-null  object
# ...

# %% [markdown]
# ## Now we have selected columns we need to find how many null values each columns have

# %%
for column in selected_columns:
    print(column)
    print(df_selected[column].isnull().value_counts())
# Out:
# Country
# Country
# False    11398
# Name: count, dtype: int64
# Age
# Age
# False    11111
# True       287
# Name: count, dtype: int64
# Gender
# Gender
# False    11325
# True        73
# Name: count, dtype: int64
# EdLevel
# EdLevel
# False    11286
# True       112
# Name: count, dtype: int64
# UndergradMajor
# UndergradMajor
# False    10661
# True       737
# Name: count, dtype: int64
# OrgSize
# OrgSize
# False    11302
# True        96
# Name: count, dtype: int64
# YearsCode
# YearsCode
# False    11389
# True         9
# Name: count, dtype: int64
# YearsCodePro
# YearsCodePro
# False    11382
# True        16
# Name: count, dtype: int64
# JobSat
# JobSat
# False    11397
# True         1
# Name: count, dtype: int64
# JobSeek
# JobSeek
# False    11398
# Name: count, dtype: int64
# CurrencySymbol
# CurrencySymbol
# False    11398
# Name: count, dtype: int64
# LanguageWorkedWith
# LanguageWorkedWith
# False    11387
# True        11
# Name: count, dtype: int64
# ...

# %%
df_selected.shape
# Out:
# (11398, 19)

# %%
df_selected.describe()
# Out:
#                 Age   WorkWeekHrs
# count  11111.000000  11276.000000
# mean      30.778895     42.064606
# std        7.393686     24.672741
# min       16.000000      3.000000
# 25%       25.000000     40.000000
# 50%       29.000000     40.000000
# 75%       35.000000     43.000000
# max       99.000000   1012.000000

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11398 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 11398 non-null  object
#  1   Age                     11111 non-null  float64
#  2   Gender                  11325 non-null  object
#  3   EdLevel                 11286 non-null  object
#  4   UndergradMajor          10661 non-null  object
#  5   OrgSize                 11302 non-null  object
#  6   YearsCode               11389 non-null  object
#  7   YearsCodePro            11382 non-null  object
#  8   JobSat                  11397 non-null  object
#  9   JobSeek                 11398 non-null  object
#  10  CurrencySymbol          11398 non-null  object
#  11  LanguageWorkedWith      11387 non-null  object
#  12  LanguageDesireNextYear  11264 non-null  object
#  13  OpenSource              11317 non-null  object
# ...

# %%
df_selected['Age1stCode'].unique()
# Out:
# array(['16', '11', '17', '18', '13', '12', '19', '21', '8', '20', '14',
#        '6', '15', '10', '29', '9', '23', '22', '30', '7', '27', '24',
#        'Younger than 5 years', '26', '25', nan, '38', '28', '5', '31',
#        '36', '34', '32', '33', '35', '40', '37', '43', '39', '42', '45'],
#       dtype=object)

# %%
df_selected['Age1stCode'] = pd.to_numeric(df_selected['Age1stCode'],errors='coerce')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\1547732176.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Age1stCode'] = pd.to_numeric(df_selected['Age1stCode'],errors='coerce')

# %%
df.replace('Younger than 5 years',5)
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11398 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 11398 non-null  object
#  1   Age                     11111 non-null  float64
#  2   Gender                  11325 non-null  object
#  3   EdLevel                 11286 non-null  object
#  4   UndergradMajor          10661 non-null  object
#  5   OrgSize                 11302 non-null  object
#  6   YearsCode               11389 non-null  object
#  7   YearsCodePro            11382 non-null  object
#  8   JobSat                  11397 non-null  object
#  9   JobSeek                 11398 non-null  object
#  10  CurrencySymbol          11398 non-null  object
#  11  LanguageWorkedWith      11387 non-null  object
#  12  LanguageDesireNextYear  11264 non-null  object
#  13  OpenSource              11317 non-null  object
# ...

# %%
import numpy as np

# %%
avg_age= df_selected['Age'].mean()
df_selected['Age'].replace(np.nan,avg_age,inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\270374862.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Age'].replace(np.nan,avg_age,inplace=True)

# %%
df_selected['Gender'].unique()
# Out:
# array(['Man', 'Woman',
#        'Non-binary, genderqueer, or gender non-conforming', nan,
#        'Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man',
#        'Woman;Man;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Non-binary, genderqueer, or gender non-conforming'],
#       dtype=object)

# %%
df_selected.replace([
       'Non-binary, genderqueer, or gender non-conforming',
       'Woman;Non-binary, genderqueer, or gender non-conforming',
       'Woman;Man',
       'Woman;Man;Non-binary, genderqueer, or gender non-conforming',
       'Man;Non-binary, genderqueer, or gender non-conforming'],'Others',inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\4117268321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.replace([

# %%
df_selected['Gender'].unique()
# Out:
# array(['Man', 'Woman', 'Others', nan], dtype=object)

# %%
df_selected.dropna(subset='Gender',inplace=True,axis=0)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\2438217287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.dropna(subset='Gender',inplace=True,axis=0)

# %%
df_selected['Gender'].unique()
# Out:
# array(['Man', 'Woman', 'Others'], dtype=object)

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11325 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 11325 non-null  object
#  1   Age                     11325 non-null  float64
#  2   Gender                  11325 non-null  object
#  3   EdLevel                 11214 non-null  object
#  4   UndergradMajor          10596 non-null  object
#  5   OrgSize                 11231 non-null  object
#  6   YearsCode               11316 non-null  object
#  7   YearsCodePro            11309 non-null  object
#  8   JobSat                  11324 non-null  object
#  9   JobSeek                 11325 non-null  object
#  10  CurrencySymbol          11325 non-null  object
#  11  LanguageWorkedWith      11314 non-null  object
#  12  LanguageDesireNextYear  11191 non-null  object
#  13  OpenSource              11244 non-null  object
# ...

# %%
df_selected.dropna(subset='EdLevel',inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\3409648010.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.dropna(subset='EdLevel',inplace=True)

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11214 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 11214 non-null  object
#  1   Age                     11214 non-null  float64
#  2   Gender                  11214 non-null  object
#  3   EdLevel                 11214 non-null  object
#  4   UndergradMajor          10490 non-null  object
#  5   OrgSize                 11121 non-null  object
#  6   YearsCode               11205 non-null  object
#  7   YearsCodePro            11198 non-null  object
#  8   JobSat                  11213 non-null  object
#  9   JobSeek                 11214 non-null  object
#  10  CurrencySymbol          11214 non-null  object
#  11  LanguageWorkedWith      11203 non-null  object
#  12  LanguageDesireNextYear  11080 non-null  object
#  13  OpenSource              11134 non-null  object
# ...

# %%
df_selected.dropna(subset='UndergradMajor',inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\364930969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.dropna(subset='UndergradMajor',inplace=True)

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10490 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 10490 non-null  object
#  1   Age                     10490 non-null  float64
#  2   Gender                  10490 non-null  object
#  3   EdLevel                 10490 non-null  object
#  4   UndergradMajor          10490 non-null  object
#  5   OrgSize                 10404 non-null  object
#  6   YearsCode               10481 non-null  object
#  7   YearsCodePro            10477 non-null  object
#  8   JobSat                  10489 non-null  object
#  9   JobSeek                 10490 non-null  object
#  10  CurrencySymbol          10490 non-null  object
#  11  LanguageWorkedWith      10479 non-null  object
#  12  LanguageDesireNextYear  10363 non-null  object
#  13  OpenSource              10413 non-null  object
# ...

# %%
df_selected['OrgSize'].unique()
# Out:
# array(['100 to 499 employees', '10 to 19 employees', '20 to 99 employees',
#        '1,000 to 4,999 employees', '10,000 or more employees',
#        '2-9 employees', '500 to 999 employees',
#        '5,000 to 9,999 employees', nan,
#        'Just me - I am a freelancer, sole proprietor, etc.'], dtype=object)

# %%
df_selected.dropna(subset='OrgSize',axis=0, inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\2612513947.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.dropna(subset='OrgSize',axis=0, inplace=True)

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10404 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 10404 non-null  object
#  1   Age                     10404 non-null  float64
#  2   Gender                  10404 non-null  object
#  3   EdLevel                 10404 non-null  object
#  4   UndergradMajor          10404 non-null  object
#  5   OrgSize                 10404 non-null  object
#  6   YearsCode               10395 non-null  object
#  7   YearsCodePro            10391 non-null  object
#  8   JobSat                  10403 non-null  object
#  9   JobSeek                 10404 non-null  object
#  10  CurrencySymbol          10404 non-null  object
#  11  LanguageWorkedWith      10393 non-null  object
#  12  LanguageDesireNextYear  10278 non-null  object
#  13  OpenSource              10328 non-null  object
# ...

# %%
df_selected['YearsCode'].unique()
# Out:
# array(['3', '12', '17', '5', '14', '8', '2', '30', '9', '26', '15', '7',
#        '13', '1', '6', '28', '4', '20', '11', '33', '10', '41', '16',
#        '23', '35', '18', '22', '19', '21', '25', '36', 'Less than 1 year',
#        '32', '27', '24', '34', '31', '39', '29', '40', '44', '37', '45',
#        '43', '38', nan, '47', '42', '50', '46', '49', '48'], dtype=object)

# %%
df_selected.replace('Less than 1 year',1,inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\2543605961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.replace('Less than 1 year',1,inplace=True)

# %%
avg_YearCode= df_selected['YearsCode'].astype('float').mean()
avg_YearCode
avg_YearCodePro= df_selected['YearsCodePro'].astype('float').mean()
avg_YearCodePro

df_selected['YearsCode'].fillna(avg_YearCode,inplace=True)
df_selected['YearsCodePro'].fillna(avg_YearCode,inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\3865560112.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['YearsCode'].fillna(avg_YearCode,inplace=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\3865560112.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['YearsCodePro'].fillna(avg_YearCode,inplace=True)

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10404 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 10404 non-null  object
#  1   Age                     10404 non-null  float64
#  2   Gender                  10404 non-null  object
#  3   EdLevel                 10404 non-null  object
#  4   UndergradMajor          10404 non-null  object
#  5   OrgSize                 10404 non-null  object
#  6   YearsCode               10404 non-null  object
#  7   YearsCodePro            10404 non-null  object
#  8   JobSat                  10403 non-null  object
#  9   JobSeek                 10404 non-null  object
#  10  CurrencySymbol          10404 non-null  object
#  11  LanguageWorkedWith      10393 non-null  object
#  12  LanguageDesireNextYear  10278 non-null  object
#  13  OpenSource              10328 non-null  object
# ...

# %%
df_selected['JobSat'].value_counts()
# Out:
# JobSat
# Slightly satisfied                    3628
# Very satisfied                        3209
# Slightly dissatisfied                 1685
# Neither satisfied nor dissatisfied    1177
# Very dissatisfied                      704
# Name: count, dtype: int64

# %%
df_selected['JobSat'].fillna('Slightly satisfied',inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\2947932109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['JobSat'].fillna('Slightly satisfied',inplace=True)

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10404 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 10404 non-null  object
#  1   Age                     10404 non-null  float64
#  2   Gender                  10404 non-null  object
#  3   EdLevel                 10404 non-null  object
#  4   UndergradMajor          10404 non-null  object
#  5   OrgSize                 10404 non-null  object
#  6   YearsCode               10404 non-null  object
#  7   YearsCodePro            10404 non-null  object
#  8   JobSat                  10404 non-null  object
#  9   JobSeek                 10404 non-null  object
#  10  CurrencySymbol          10404 non-null  object
#  11  LanguageWorkedWith      10393 non-null  object
#  12  LanguageDesireNextYear  10278 non-null  object
#  13  OpenSource              10328 non-null  object
# ...

# %%
df_selected['LanguageWorkedWith'].fillna('C#;HTML/CSS;JavaScript;SQL',inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\2563078362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['LanguageWorkedWith'].fillna('C#;HTML/CSS;JavaScript;SQL',inplace=True)

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10404 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 10404 non-null  object
#  1   Age                     10404 non-null  float64
#  2   Gender                  10404 non-null  object
#  3   EdLevel                 10404 non-null  object
#  4   UndergradMajor          10404 non-null  object
#  5   OrgSize                 10404 non-null  object
#  6   YearsCode               10404 non-null  object
#  7   YearsCodePro            10404 non-null  object
#  8   JobSat                  10404 non-null  object
#  9   JobSeek                 10404 non-null  object
#  10  CurrencySymbol          10404 non-null  object
#  11  LanguageWorkedWith      10404 non-null  object
#  12  LanguageDesireNextYear  10278 non-null  object
#  13  OpenSource              10328 non-null  object
# ...

# %%
df_selected['LanguageDesireNextYear'].fillna('Python',inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\651659662.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['LanguageDesireNextYear'].fillna('Python',inplace=True)

# %%
df_selected['OpenSource'].fillna('The quality of OSS and closed source software is about the same',inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\112204470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['OpenSource'].fillna('The quality of OSS and closed source software is about the same',inplace=True)

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10404 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 10404 non-null  object
#  1   Age                     10404 non-null  float64
#  2   Gender                  10404 non-null  object
#  3   EdLevel                 10404 non-null  object
#  4   UndergradMajor          10404 non-null  object
#  5   OrgSize                 10404 non-null  object
#  6   YearsCode               10404 non-null  object
#  7   YearsCodePro            10404 non-null  object
#  8   JobSat                  10404 non-null  object
#  9   JobSeek                 10404 non-null  object
#  10  CurrencySymbol          10404 non-null  object
#  11  LanguageWorkedWith      10404 non-null  object
#  12  LanguageDesireNextYear  10404 non-null  object
#  13  OpenSource              10404 non-null  object
# ...

# %%
df_selected['Student'].unique()
# Out:
# array(['No', 'Yes, full-time', 'Yes, part-time', nan], dtype=object)

# %%
df_selected['Student'].value_counts()
# Out:
# Student
# No                8904
# Yes, full-time     882
# Yes, part-time     573
# Name: count, dtype: int64

# %%
df_selected['Student'].fillna('No',inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\2928616000.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Student'].fillna('No',inplace=True)

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10404 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 10404 non-null  object
#  1   Age                     10404 non-null  float64
#  2   Gender                  10404 non-null  object
#  3   EdLevel                 10404 non-null  object
#  4   UndergradMajor          10404 non-null  object
#  5   OrgSize                 10404 non-null  object
#  6   YearsCode               10404 non-null  object
#  7   YearsCodePro            10404 non-null  object
#  8   JobSat                  10404 non-null  object
#  9   JobSeek                 10404 non-null  object
#  10  CurrencySymbol          10404 non-null  object
#  11  LanguageWorkedWith      10404 non-null  object
#  12  LanguageDesireNextYear  10404 non-null  object
#  13  OpenSource              10404 non-null  object
# ...

# %%
avg_Age1st = df_selected['Age1stCode'].mean()
df_selected['Age1stCode'].fillna(avg_Age1st,inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\3108154496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Age1stCode'].fillna(avg_Age1st,inplace=True)

# %%
df_selected['WorkLoc'].fillna('Office',inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\642658875.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['WorkLoc'].fillna('Office',inplace=True)

# %%
df_selected['WorkWeekHrs'].unique()
# Out:
# array([ 80.  ,  32.  ,  40.  ,  45.  ,   8.  , 140.  ,  37.  ,  39.  ,
#         50.  ,  42.  ,   7.  ,  70.  ,  38.  ,  44.  ,  35.  ,   6.  ,
#           nan,  75.  ,  48.  ,  30.  ,  36.  ,  34.  ,  98.  ,   9.  ,
#         37.5 ,  60.  ,  20.  ,  55.  , 100.  ,  43.  ,  41.  ,  42.5 ,
#         36.75,  38.5 ,  16.  ,  10.  ,  52.  ,  15.  ,   8.5 ,  12.  ,
#         33.  ,  36.2 ,  46.  ,  47.  ,  49.  ,  65.  ,   7.25,  58.  ,
#          4.  ,  28.  ,  36.25,   9.25,  24.  ,  11.  ,  36.5 ,  25.  ,
#         56.  ,  62.  ,  41.5 ,  63.  ,  21.  ,  72.  ,  51.  , 150.  ,
#         90.  ,  54.  ,  17.  ,  14.  ,  22.  ,   7.5 ,   5.  ,  47.5 ,
#        113.  ,  45.5 ,  85.  ,  32.5 ,  84.  ,  57.  ,  64.  ,  13.  ,
#         31.5 ,  79.  ,  29.  , 145.  ,  31.  ,   6.3 ,  23.  ,  37.75,
#         19.  ,  34.5 ,   3.  ,  74.  ,  18.  ,   9.6 ,   8.2 ,  33.5 ,
#         72.5 ,  61.  ])

# %%
fake_hours= [160,375,385,168,475,1012,425,165,130]

# %%
import numpy as np

# %%
df_selected['WorkWeekHrs'].replace(fake_hours,np.nan,inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\4251230552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['WorkWeekHrs'].replace(fake_hours,np.nan,inplace=True)

# %%
avg_WeekHrs = df_selected['WorkWeekHrs'].mean()
df_selected['WorkWeekHrs'].fillna(avg_WeekHrs,inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4632\2845408022.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['WorkWeekHrs'].fillna(avg_WeekHrs,inplace=True)

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10404 entries, 0 to 11551
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 10404 non-null  object
#  1   Age                     10404 non-null  float64
#  2   Gender                  10404 non-null  object
#  3   EdLevel                 10404 non-null  object
#  4   UndergradMajor          10404 non-null  object
#  5   OrgSize                 10404 non-null  object
#  6   YearsCode               10404 non-null  object
#  7   YearsCodePro            10404 non-null  object
#  8   JobSat                  10404 non-null  object
#  9   JobSeek                 10404 non-null  object
#  10  CurrencySymbol          10404 non-null  object
#  11  LanguageWorkedWith      10404 non-null  object
#  12  LanguageDesireNextYear  10404 non-null  object
#  13  OpenSource              10404 non-null  object
# ...

# %%
df_selected.to_csv('Cleaned.csv')
